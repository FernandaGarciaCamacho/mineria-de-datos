# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaGarciaCamacho/mineria-de-datos/blob/main/Mineria_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria de Datos

# %% [markdown]
# ## Primer Parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# ##### Mineria de datos

# %% [markdown]
# Actividad para extracción de datos, donde se busca encontrar patrónes de datos para a su vez optimizar actividades. Se utiliza para procesar y explorar grandes conjuntos de datos. Es el proceso de analizar grandes volúmenes de datos para descubrir patrones, anomalías y correlaciones ocultas, transformando así datos brutos en conocimiento valioso para la toma de decisiones estratégicas, la predicción de tendencias y la optimización de procesos en diversas industrias, utilizando técnicas de estadística, inteligencia artificial y aprendizaje automático.

# %% [markdown]
# ##### Ciencia de Datos

# %% [markdown]
# La ciencia de datos es el estudio de datos con el fin de extraer información significativa. Es el estudio científico de los datos para obtener conocimientos. La Ciencia de Datos es un campo multidisciplinario que combina estadística, matemáticas, inteligencia artificial y computación para analizar grandes volúmenes de datos y extraer conocimiento significativo, patrones y tendencias, con el fin de apoyar la toma de decisiones, hacer predicciones y resolver problemas en diversas industrias.

# %% [markdown]
# #### Ciencia de Datos

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?

# %%
L = [1, 2, 3]

# %%
L?

# %%
def square(a):
  """Return the square of a."""
  return a ** 2

# %%
square?

# %%
square??

# %%
len??

# %%
L.append
# Out:
# <function list.append(object, /)>

# %%
L.clear
# Out:
# <function list.clear()>

# %%
L.count
# Out:
# <function list.count(value, /)>

# %%
L.__add__
# Out:
# <method-wrapper '__add__' of list object at 0x7f3cf43e7700>

# %%
from itertools import combinations

# %%
import h11

# %%
*Warning?

# %%
str.*find*?

# %% [markdown]
# IPython Magic Commands

# %%
#El comando magico sirve para evaluar el desempeño en terminos de tiempo
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 68.8 µs ± 1.32 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#El comando magico tambien sirve para evaluar el desempeño, solo que este abarca
#varias lineas de codigo en lugar de una
# %%timeit
L = []
for n in range(1000):
  L.append(n ** 2)
# Out:
# 76.7 µs ± 1.18 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# IPython and Shell Commands

# %%
# !ls
# Out:
# sample_data

# %%
#El % te conserva ahi, ! solo es para visualizar una vez y no te conserva ahi

# %cd sample_data/
# Out:
# [Errno 2] No such file or directory: 'sample_data/'
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# !cat README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
# %env
# Out:
# {'SHELL': '/bin/bash',
#  'COLAB_JUPYTER_TRANSPORT': 'ipc',
#  'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events',
#  'VM_GCE_METADATA_HOST': '169.254.169.253',
#  'MODEL_PROXY_HOST': 'https://mp.kaggle.net',
#  'HOSTNAME': '4422516dc7cd',
#  'LANGUAGE': 'en_US',
#  'TBE_RUNTIME_ADDR': '172.28.0.1:8011',
#  'GCE_METADATA_TIMEOUT': '3',
#  'COLAB_JUPYTER_IP': '172.28.0.12',
#  'COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL': 'http://172.28.0.1:8013/',
#  'KMP_LISTEN_PORT': '6000',
#  'TF_FORCE_GPU_ALLOW_GROWTH': 'true',
#  'ENV': '/root/.bashrc',
#  'PWD': '/',
#  'TBE_EPHEM_CREDS_ADDR': '172.28.0.1:8009',
#  'COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT': '30s',
#  'TBE_CREDS_ADDR': '172.28.0.1:8008',
#  'COLAB_JUPYTER_TOKEN': '<hidden>',
#  'LAST_FORCED_REBUILD': '20250623',
#  'TCLLIBPATH': '/usr/share/tcltk/tcllib1.20',
#  'COLAB_KERNEL_MANAGER_PROXY_HOST': '172.28.0.12',
#  'UV_BUILD_CONSTRAINT': '',
#  'COLAB_WARMUP_DEFAULTS': '1',
#  'HOME': '/root',
#  'LANG': 'en_US.UTF-8',
#  'CLOUDSDK_CONFIG': '/content/.config',
#  'UV_SYSTEM_PYTHON': 'true',
#  'COLAB_RELEASE_TAG': 'release-colab-external_20260120-060051_RC00',
#  'KMP_TARGET_PORT': '9000',
#  'KMP_EXTRA_ARGS': '--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-1c6ruzci0umcn --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true ',
#  'UV_INSTALL_DIR': '/usr/local/bin',
#  'COLAB_LANGUAGE_SERVER_PROXY_LSP_DIRS': '/datalab/web/pyright/typeshed-fallback/stdlib,/usr/local/lib/python3.10/dist-packages',
#  'COLAB_KERNEL_MANAGER_PROXY_PORT': '6000',
#  'CLOUDSDK_PYTHON': 'python3',
#  'NO_GCE_CHECK': 'False',
#  'PYTHONPATH': '/env/python',
#  'SHLVL': '0',
#  'COLAB_LANGUAGE_SERVER_PROXY': '/usr/colab/bin/language_service',
#  'UV_CONSTRAINT': '',
#  'PYTHONUTF8': '1',
#  'COLAB_GPU': '',
#  'GCS_READ_CACHE_BLOCK_SIZE_MB': '16',
#  'LC_ALL': 'en_US.UTF-8',
#  'COLAB_FILE_HANDLER_ADDR': 'localhost:3453',
#  'PATH': '/opt/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin',
#  'COLAB_IMAGE_TYPE': 'cpu',
#  'COLAB_DEBUG_ADAPTER_MUX_PATH': '/usr/local/bin/dap_multiplexer',
#  'PYTHONWARNINGS': 'ignore:::pip._internal.cli.base_command',
#  'DEBIAN_FRONTEND': 'noninteractive',
#  'COLAB_BACKEND_VERSION': 'next',
#  'OLDPWD': '/',
#  '_PYVIZ_COMMS_INSTALLED': '1',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'JPY_SESSION_NAME': 'https://github.com/FernandaGarciaCamacho/mineria-de-datos/blob/main/Mineria_de_Datos.ipynb',
#  'JPY_PARENT_PID': '92',
#  'TERM': 'xterm-color',
#  'CLICOLOR': '1',
#  'PAGER': 'cat',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#  'ENABLE_DIRECTORYPREFETCHER': '1',
#  'USE_AUTH_EPHEM': '1',
#  'COLAB_NOTEBOOK_ID': 'https://github.com/FernandaGarciaCamacho/mineria-de-datos/blob/main/Mineria_de_Datos.ipynb'}

# %% [markdown]
# Understanding Data Types in Python

# %%
import numpy as np

# %%
np.array([1, 4, 2, 5, 3])
# Out:
# array([1, 4, 2, 5, 3])

# %%
np.array([3.14, 4, 2, 3])
# Out:
# array([3.14, 4.  , 2.  , 3.  ])

# %%
np.array([1, 2, 3, 4], dtype='float32')
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %%
np.array([1, 2, 3, 4], dtype='int')
# Out:
# array([1, 2, 3, 4])

# %%
#Crea un rango tomando desde i hasta i+3 (sin tomar en cuenta el ultimo)
np.array([range(i, i + 3) for i in [2, 4, 6]])
# Out:
# array([[2, 3, 4],
#        [4, 5, 6],
#        [6, 7, 8]])

# %% [markdown]
# The basics of NumPy Arrays

# %%
import numpy as np

# %%
np.random.seed(0)  # seed for reproducibility

# %%
np.random.seed(0)  # seed for reproducibility

x1 = np.random.randint(10, size=6)  # One-dimensional array
x2 = np.random.randint(10, size=(3, 4))  # Two-dimensional array
x3 = np.random.randint(10, size=(3, 4, 5))  # Three-dimensional array

# %%
print("x3 ndim: ", x3.ndim)
print("x3 shape:", x3.shape)
print("x3 size: ", x3.size)
# Out:
# x3 ndim:  3
# x3 shape: (3, 4, 5)
# x3 size:  60

# %%
print(x2.dtype)
# Out:
# int64

# %%
print("itemsize:", x3.itemsize, "bytes")
print("nbytes:", x3.nbytes, "bytes")
# Out:
# itemsize: 8 bytes
# nbytes: 480 bytes

# %% [markdown]
# Array Indexing: Accessing Single Elements

# %%
x1
# Out:
# array([5, 0, 3, 3, 7, 9])

# %%
x1[0] #Colocamos el indice del elemento a extraer, en este caso el primer elemento tiene el indice 0
# Out:
# np.int64(5)

# %%
x1[4]
# Out:
# np.int64(7)

# %%
x2
# Out:
# array([[3, 5, 2, 4],
#        [7, 6, 8, 8],
#        [1, 6, 7, 7]])

# %%
x2[0,0]
# Out:
# np.int64(3)

# %%
x2[0,2]
# Out:
# np.int64(2)

# %%
x2[2,-1]
# Out:
# np.int64(7)

# %%
x2[0,0]=12 #Asigna nuevos valores a la posición
x2
# Out:
# array([[12,  5,  2,  4],
#        [ 7,  6,  8,  8],
#        [ 1,  6,  7,  7]])

# %% [markdown]
# ####Estadistica Básica

# %%
import numpy as np

# %% [markdown]
# Media (Mean)

# %%
data = np.array([1, 2, 3, 4, 5])
media = np.mean(data)
print(media)
# Out:
# 3.0

# %% [markdown]
# Promedio (Average) y Promedio Ponderado

# %%
data = np.array([1, 2, 3, 4, 5])
weights = np.array([1, 2, 3, 4, 5])
promedio = np.average(data)
promedio_ponderado = np.average(data, weights=weights)

# %% [markdown]
# Mediana

# %%
mediana = np.median(data)

# %% [markdown]
# Varianza y Desviación Estándar

# %%
varianza = np.var(data)
desviacion = np.std(data)

# %% [markdown]
# Generación de Datos Aleatorios

# %%
muestra = np.random.normal(0, 1, 1000)
print(np.mean(muestra), np.std(muestra))
# Out:
# -0.006543456960417206 1.0059985778093545

# %% [markdown]
# Correlación

# %%
corr = np.corrcoef([1,2,3], [1,5,7])

# %% [markdown]
# Pandas

# %%
import numpy as np
import pandas as pd
from io import StringIO

# %%
raw = """Marca temporal\tNúmero de matrícula\t¿Cuántos años cumplidos tienes?\t¿Has realizado programas utilizando Python?\t¿Has utilizado Google Colab?\t¿Tienes cuenta de GitHub?
19/01/2026 18:32:18\t178920\t22\tSi\tNo\tSi
19/01/2026 18:32:23\t182712\t21\tSi\tNo\tSi
19/01/2026 18:32:25\t180370\t26\tSi\tSi\tSi
19/01/2026 18:32:27\t182570\t21\tSi\tSi\tSi
19/01/2026 18:32:28\t177622\t24\tSi\tNo\tSi
19/01/2026 18:32:29\t175166\t22\tSi\tSi\tSi
19/01/2026 18:32:30\t177573\t22\tSi\tSi\tSi
19/01/2026 18:32:35\t178430\t21\tSi\tSi\tSi
19/01/2026 18:32:38\t179169\t23\tSi\tNo\tSi
19/01/2026 18:32:41\t177263\t22\tSi\tSi\tSi
19/01/2026 18:32:48\t179884\t23\tSi\tNo\tSi
19/01/2026 18:32:48\t183016\t22\tSi\tNo\tSi
19/01/2026 18:32:50\t179033\t23\tSi\tSi\tNo
19/01/2026 18:32:54\t178218\t22\tSi\tNo\tSi
19/01/2026 18:32:55\t178446\t22\tSi\tSi\tSi
19/01/2026 18:33:00\t178166\t22\tSi\tSi\tNo
19/01/2026 18:33:02\t177406\t22\tSi\tNo\tSi
19/01/2026 18:33:05\t177192\t22\tSi\tSi\tSi
19/01/2026 18:33:08\t182451\t21\tSi\tNo\tSi
19/01/2026 18:33:08\t171513\t24\tNo\tNo\tSi
19/01/2026 18:33:09\t181619\t21\tSi\tNo\tSi
19/01/2026 18:33:12\t182298\t23\tSi\tNo\tSi
19/01/2026 18:33:14\t181419\t24\tNo\tNo\tSi
19/01/2026 18:33:32\t177291\t21\tSi\tSi\tSi
19/01/2026 18:33:42\t182085\t22\tSi\tNo\tSi
19/01/2026 18:33:53\t176453\t22\tSi\tNo\tSi
19/01/2026 18:34:04\t176263\t24\tSi\tNo\tSi
19/01/2026 18:34:06\t179997\t21\tSi\tNo\tSi
19/01/2026 18:36:21\t175842\t23\tSi\tNo\tNo
19/01/2026 20:19:21\t179913\t20\tSi\tNo\tSi
19/01/2026 20:19:48\t177301\t22\tSi\tSi\tNo
19/01/2026 20:20:06\t183060\t21\tSi\tNo\tSi
19/01/2026 20:20:08\t177935\t22\tSi\tSi\tSi
19/01/2026 20:20:19\t177700\t20\tSi\tSi\tSi
19/01/2026 20:20:26\t178318\t24\tSi\tSi\tSi
19/01/2026 20:20:27\t174653\t24\tSi\tNo\tSi
19/01/2026 20:20:29\t177139\t21\tSi\tNo\tSi
19/01/2026 20:20:31\t173479\t25\tSi\tNo\tNo
19/01/2026 20:20:39\t175588\t23\tNo\tNo\tSi
19/01/2026 20:20:45\t178774\t23\tSi\tSi\tSi
19/01/2026 20:20:45\t175031\t23\tSi\tNo\tNo
19/01/2026 20:20:49\t178396\t21\tSi\tSi\tSi
19/01/2026 20:20:49\t172068\t23\tNo\tNo\tNo
19/01/2026 20:20:50\t174197\t23\tNo\tNo\tSi
19/01/2026 20:20:55\t178584\t22\tSi\tNo\tSi
19/01/2026 20:20:55\t175329\t24\tSi\tNo\tSi
19/01/2026 20:20:56\t177685\t22\tSi\tSi\tSi
19/01/2026 20:20:57\t178678\t22\tNo\tNo\tSi
19/01/2026 20:21:04\t177143\t22\tSi\tNo\tSi
19/01/2026 20:21:07\t182318\t26\tSi\tNo\tSi
19/01/2026 20:21:27\t182377\t20\tSi\tNo\tSi
19/01/2026 20:21:34\t179419\t22\tSi\tNo\tNo
19/01/2026 20:21:35\t181662\t21\tSi\tNo\tSi
19/01/2026 20:21:38\t181760\t21\tSi\tNo\tSi
19/01/2026 20:22:06\t177888\t22\tSi\tNo\tSi
19/01/2026 20:22:15\t176535\t25\tSi\tNo\tSi
19/01/2026 20:22:29\t179862\t21\tSi\tNo\tSi
19/01/2026 20:22:32\t178378\t22\tSi\tNo\tSi
19/01/2026 20:22:50\t177451\t22\tSi\tNo\tSi
19/01/2026 20:23:15\t179804\t21\tSi\tNo\tSi
"""

#Cuando Panda lee los archivos, carga automaticamente los encabezados (lista de encabezados)
# Cargar datos
df = pd.read_csv(StringIO(raw), sep='\t') #Convierte/lee a texto separado por \t
df.columns = [c.strip() for c in df.columns] # De cada columna elimina espacios

# Variables
df['edad'] = pd.to_numeric(df['¿Cuántos años cumplidos tienes?'], errors='coerce') #De texto a numero y si hay un error lo ignora
map_sn = {'Si': True, 'No': False} #Mapeo (si es si true, si no false)
df['prog_python'] = df['¿Has realizado programas utilizando Python?'].map(map_sn) #Mapea los valores y si en la columna existe un si a verdaderos, y si no a false.
df['usa_colab'] = df['¿Has utilizado Google Colab?'].map(map_sn) #Vuelve a hacer el mapeo en toda la columna
df['cuenta_github'] = df['¿Tienes cuenta de GitHub?'].map(map_sn)#Vuelve a hacer el mapeo en toda la columna
#Lit toma todas las columnas con los si y no (de las preguntas) y cambia los si por los true y los no por los false

# A NumPy
edad = df['edad'].to_numpy(dtype=float) #Cambia el dato a flotante
prog_py = df['prog_python'].to_numpy(dtype=bool) #Cambia a numpy tipo booleano
usa_colab = df['usa_colab'].to_numpy(dtype=bool) #La convierte a numpay tipo booleano
cuenta_gh = df['cuenta_github'].to_numpy(dtype=bool)#La convierte a numpay tipo booleano

# Descriptivos de edad (NumPy) DICCIONARIO
summary_age = {
    'n': int(edad.size), #Cuantos arreglos tiene edad
    'min': float(np.min(edad)), #Trae la menor edad
    'p25': float(np.percentile(edad, 25)), #25% de los elementos. Ordena los datos y toma el primer 25%
    'mediana': float(np.median(edad)), #Toma la mediana (el de enmedio)
    'media': float(np.mean(edad)), #Toma la media (promedio)
    'p75': float(np.percentile(edad, 75)), #75% de las edades
    'max': float(np.max(edad)), #Edad maxima
    'rango(ptp)': float(np.ptp(edad)), #Rango, Pico minimo
    'var_muestral': float(np.var(edad, ddof=1)), #Varianza
    'std_muestral': float(np.std(edad, ddof=1)), #Desviación estandar. Medida de disperción
    'cv': float(np.std(edad, ddof=1)/np.mean(edad)), #Coeficiente de variación estandar
}

# Frecuencias (NumPy) Cantidad de elementos
freq_python = {'Si': int(np.count_nonzero(prog_py)), 'No': int(edad.size - np.count_nonzero(prog_py))}
freq_colab  = {'Si': int(np.count_nonzero(usa_colab)), 'No': int(edad.size - np.count_nonzero(usa_colab))}
freq_gh     = {'Si': int(np.count_nonzero(cuenta_gh)), 'No': int(edad.size - np.count_nonzero(cuenta_gh))}

# Tablas cruzadas (NumPy)
def tabla2x2(a, b):
    t = np.zeros((2,2), dtype=int)
    t[1,1] = np.count_nonzero(a & b)
    t[1,0] = np.count_nonzero(a & ~b)
    t[0,1] = np.count_nonzero(~a & b)
    t[0,0] = np.count_nonzero(~a & ~b)
    return t

tab_py_colab = tabla2x2(prog_py, usa_colab)
tab_py_gh    = tabla2x2(prog_py, cuenta_gh)
tab_colab_gh = tabla2x2(usa_colab, cuenta_gh)

# Medias de edad por grupo (NumPy)
means_by_group = {
    'edad_promedio_Python': {'Si': float(np.mean(edad[prog_py])) if np.any(prog_py) else np.nan,
                             'No': float(np.mean(edad[~prog_py])) if np.any(~prog_py) else np.nan},
    'edad_promedio_Colab':  {'Si': float(np.mean(edad[usa_colab])) if np.any(usa_colab) else np.nan,
                             'No': float(np.mean(edad[~usa_colab])) if np.any(~usa_colab) else np.nan},
    'edad_promedio_GitHub': {'Si': float(np.mean(edad[cuenta_gh])) if np.any(cuenta_gh) else np.nan,
                             'No': float(np.mean(edad[~cuenta_gh])) if np.any(~cuenta_gh) else np.nan},
}

summary_age, freq_python, freq_colab, freq_gh, tab_py_colab, tab_py_gh, tab_colab_gh, means_by_group
# Out:
# ({'n': 60,
#   'min': 20.0,
#   'p25': 21.0,
#   'mediana': 22.0,
#   'media': 22.3,
#   'p75': 23.0,
#   'max': 26.0,
#   'rango(ptp)': 6.0,
#   'var_muestral': 1.8406779661016948,
#   'std_muestral': 1.3567158752302173,
#   'cv': 0.06083927691615324},
#  {'Si': 54, 'No': 6},
#  {'Si': 18, 'No': 42},
#  {'Si': 52, 'No': 8},
#  array([[ 6,  0],
#         [36, 18]]),
#  array([[ 1,  5],
#         [ 7, 47]]),
#  array([[ 5, 37],
#         [ 3, 15]]),
#  {'edad_promedio_Python': {'Si': 22.203703703703702, 'No': 23.166666666666668},
#   'edad_promedio_Colab': {'Si': 22.11111111111111, 'No': 22.38095238095238},
#   'edad_promedio_GitHub': {'Si': 22.21153846153846, 'No': 22.875}})

# %%
df.head() #Muestra la tabla resultanter
# Out:
#         Marca temporal  Número de matrícula  ¿Cuántos años cumplidos tienes?  \
# 0  19/01/2026 18:32:18               178920                               22
# 1  19/01/2026 18:32:23               182712                               21
# 2  19/01/2026 18:32:25               180370                               26
# 3  19/01/2026 18:32:27               182570                               21
# 4  19/01/2026 18:32:28               177622                               24
#
#   ¿Has realizado programas utilizando Python? ¿Has utilizado Google Colab?  \
# 0                                          Si                           No
# 1                                          Si                           No
# 2                                          Si                           Si
# 3                                          Si                           Si
# 4                                          Si                           No
#
#   ¿Tienes cuenta de GitHub?  edad  prog_python  usa_colab  cuenta_github
# 0                        Si    22         True      False           True
# 1                        Si    21         True      False           True
# 2                        Si    26         True       True           True
# 3                        Si    21         True       True           True
# 4                        Si    24         True      False           True

# %%
# A NumPy
edad = df['edad'].to_numpy(dtype=float) #Cambia el dato a flotante
prog_py = df['prog_python'].to_numpy(dtype=bool) #Cambia a numpy tipo booleano
usa_colab = df['usa_colab'].to_numpy(dtype=bool) #La convierte a numpay tipo booleano
cuenta_gh = df['cuenta_github'].to_numpy(dtype=bool)#La convierte a numpay tipo booleano

# %%
edad
# Out:
# array([22., 21., 26., 21., 24., 22., 22., 21., 23., 22., 23., 22., 23.,
#        22., 22., 22., 22., 22., 21., 24., 21., 23., 24., 21., 22., 22.,
#        24., 21., 23., 20., 22., 21., 22., 20., 24., 24., 21., 25., 23.,
#        23., 23., 21., 23., 23., 22., 24., 22., 22., 22., 26., 20., 22.,
#        21., 21., 22., 25., 21., 22., 22., 21.])

# %%
edad[:5]
# Out:
# array([22., 21., 26., 21., 24.])

# %%
prog_py[:5]
# Out:
# array([ True,  True,  True,  True,  True])

# %%
# Descriptivos de edad (NumPy) DICCIONARIO
summary_age = {
    'n': int(edad.size), #Cuantos arreglos tiene edad
    'min': float(np.min(edad)), #Trae la menor edad
    'p25': float(np.percentile(edad, 25)), #25% de los elementos. Ordena los datos y toma el primer 25%
    'mediana': float(np.median(edad)), #Toma la mediana (el de enmedio)
    'media': float(np.mean(edad)), #Toma la media (promedio)
    'p75': float(np.percentile(edad, 75)), #75% de las edades
    'max': float(np.max(edad)), #Edad maxima
    'rango(ptp)': float(np.ptp(edad)), #Rango, Pico minimo
    'var_muestral': float(np.var(edad, ddof=1)), #Varianza
    'std_muestral': float(np.std(edad, ddof=1)), #Desviación estandar. Medida de disperción
    'cv': float(np.std(edad, ddof=1)/np.mean(edad)), #Coeficiente de variación estandar
}

# %%
summary_age
# Out:
# {'n': 60,
#  'min': 20.0,
#  'p25': 21.0,
#  'mediana': 22.0,
#  'media': 22.3,
#  'p75': 23.0,
#  'max': 26.0,
#  'rango(ptp)': 6.0,
#  'var_muestral': 1.8406779661016948,
#  'std_muestral': 1.3567158752302173,
#  'cv': 0.06083927691615324}

# %%
# Frecuencias (NumPy) Cantidad de elementos
freq_python = {'Si': int(np.count_nonzero(prog_py)), 'No': int(edad.size - np.count_nonzero(prog_py))}
freq_colab  = {'Si': int(np.count_nonzero(usa_colab)), 'No': int(edad.size - np.count_nonzero(usa_colab))}
freq_gh     = {'Si': int(np.count_nonzero(cuenta_gh)), 'No': int(edad.size - np.count_nonzero(cuenta_gh))}

# %%
print(f'Frecuencia de utilización de Python:{freq_python}') #Cuantos por cada "respuesta"
print(f'Frecuencia de utilización de Colab:{freq_colab}')
print(f'Frecuencia de utilización de GitHub:{freq_gh}')
# Out:
# Frecuencia de utilización de Python:{'Si': 54, 'No': 6}
# Frecuencia de utilización de Colab:{'Si': 18, 'No': 42}
# Frecuencia de utilización de GitHub:{'Si': 52, 'No': 8}

# %%
# Tablas cruzadas (NumPy)
def tabla2x2(a, b):
    t = np.zeros((2,2), dtype=int) #Genera una matriz de 2x2 de tipo entero y lo llena de 0
    t[1,1] = np.count_nonzero(a & b) #En la posición 1,1 se le asigna de la cuenta de los que no son 0 entre a and b (hace un AND) (0x0=0, 0x1=0, 1x0=0, 1x1=1)
    t[1,0] = np.count_nonzero(a & ~b) #En la posición 1,0 es un AND negando la b
    t[0,1] = np.count_nonzero(~a & b) #En la posición 0,1 es un AND con la b negada
    t[0,0] = np.count_nonzero(~a & ~b) #En la posición 0,0 es un AND negando a y b
    return t

tab_py_colab = tabla2x2(prog_py, usa_colab)
tab_py_gh    = tabla2x2(prog_py, cuenta_gh)
tab_colab_gh = tabla2x2(usa_colab, cuenta_gh)

# %%
print(f'Tabla 2x2 de Python y Colab \n {tab_py_colab}')

#SEGUN LOS RESULTADOS:
#6 no saben usar ni python ni colab
#0 no sabe usar python y no sabe usar colab
#36 sabe usar python pero no colab
#18 sabe usar python y colab
# Out:
# Tabla 2x2 de Python y Colab
#  [[ 6  0]
#  [36 18]]

# %%
print(f'Tabla 2x2 de Python y GitHun \n {tab_py_gh}')
# Out:
# Tabla 2x2 de Python y GitHun
#  [[ 1  5]
#  [ 7 47]]

# %%
# Medias de edad por grupo (NumPy)
means_by_group = {
    'edad_promedio_Python': {'Si': float(np.mean(edad[prog_py])) if np.any(prog_py) else np.nan,
                             'No': float(np.mean(edad[~prog_py])) if np.any(~prog_py) else np.nan},
    'edad_promedio_Colab':  {'Si': float(np.mean(edad[usa_colab])) if np.any(usa_colab) else np.nan,
                             'No': float(np.mean(edad[~usa_colab])) if np.any(~usa_colab) else np.nan},
    'edad_promedio_GitHub': {'Si': float(np.mean(edad[cuenta_gh])) if np.any(cuenta_gh) else np.nan,
                             'No': float(np.mean(edad[~cuenta_gh])) if np.any(~cuenta_gh) else np.nan},
}

summary_age, freq_python, freq_colab, freq_gh, tab_py_colab, tab_py_gh, tab_colab_gh, means_by_group
# Out:
# ({'n': 60,
#   'min': 20.0,
#   'p25': 21.0,
#   'mediana': 22.0,
#   'media': 22.3,
#   'p75': 23.0,
#   'max': 26.0,
#   'rango(ptp)': 6.0,
#   'var_muestral': 1.8406779661016948,
#   'std_muestral': 1.3567158752302173,
#   'cv': 0.06083927691615324},
#  {'Si': 54, 'No': 6},
#  {'Si': 18, 'No': 42},
#  {'Si': 52, 'No': 8},
#  array([[ 6,  0],
#         [36, 18]]),
#  array([[ 1,  5],
#         [ 7, 47]]),
#  array([[ 5, 37],
#         [ 3, 15]]),
#  {'edad_promedio_Python': {'Si': 22.203703703703702, 'No': 23.166666666666668},
#   'edad_promedio_Colab': {'Si': 22.11111111111111, 'No': 22.38095238095238},
#   'edad_promedio_GitHub': {'Si': 22.21153846153846, 'No': 22.875}})
